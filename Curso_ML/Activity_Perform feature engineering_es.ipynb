# %% [markdown]
# # Actividad: Realizar ingeniería de características

# %% [markdown]
# ## **Introducción**
#
#
# Mientras aprendes, los profesionales de datos que trabajan en proyectos de modelado utilizan ingeniería de características para ayudarlos a determinar qué atributos en los datos pueden predecir mejor ciertas medidas.
#
# En esta actividad, estás trabajando para una empresa que proporciona información a la Asociación Nacional de Baloncesto (NBA), una liga profesional de baloncesto en Norteamérica. Ayudarás a los gerentes y entrenadores de la NBA a identificar qué jugadores tienen más probabilidades de prosperar en el entorno de alta presión del baloncesto profesional y ayudar al equipo a tener éxito con el tiempo.
#
# Para hacer esto, analizarás un subconjunto de datos que contiene información sobre jugadores de la NBA y sus registros de rendimiento. Realizarás ingeniería de características para determinar qué características predicen de manera más efectiva si la carrera de un jugador en la NBA durará al menos cinco años. Los conocimientos obtenidos luego se utilizarán en la siguiente etapa del proyecto: construir el modelo predictivo.

# %% [markdown]
# ## **Paso 1: Importaciones**

# %% [markdown]
# Comienza importando `pandas`.

# %%
# Import pandas.

### YOUR CODE HERE ###

# %% [markdown]
# El conjunto de datos es un archivo .csv llamado `nba-players.csv`. Consiste en registros de rendimiento para un subconjunto de jugadores de la NBA. Como se muestra en esta celda, el conjunto de datos ha sido cargado automáticamente para ti. No necesitas descargar el archivo .csv, ni proporcionar más código, para acceder al conjunto de datos y proceder con este laboratorio. Por favor, continúa con esta actividad completando las siguientes instrucciones.

# %%
# RUN THIS CELL TO IMPORT YOUR DATA.

# Save in a variable named `data`.

### YOUR CODE HERE ###

data = pd.read_csv("nba-players.csv", index_col=0)

# %% [markdown]
# <details><summary><h4><strong>Pista 1</strong></h4></summary>
#
# La función `read_csv()` de `pandas` permite leer datos desde un archivo csv y cargarlos en un DataFrame.
#
# </details>

# %% [markdown]
# <details><summary><h4><strong>Pista 2</strong></h4></summary>
#
# Llamar a `read_csv()`, pasar el nombre del archivo csv como una cadena, seguido de `index_col=0` para usar la primera columna del csv como índice en el DataFrame.
#
# </details>

# %% [markdown]
# ## **Paso 2: exploración de datos**

# %% [markdown]
# Mostrar las primeras 10 filas de los datos para tener una idea de qué implica.

# %%
# Display first 10 rows of data.

### YOUR CODE HERE ###

# %% [markdown]
# <details>
# <summary><h4><strong>Pista 1</strong></h4></summary>
#
# Hay una función en la biblioteca `pandas` que se puede llamar en un DataFrame para mostrar las primeras n filas, donde n es un número de tu elección.
# </details>

# %% [markdown]
# <details>
# <summary><h4><strong>Pista 2</strong></h4></summary>
#
# Llama a la función `head()` y pasa 10.
# </details>

# %% [markdown]
# Mostrar el número de filas y el número de columnas para tener una idea de cuántos datos están disponibles para ti.

# %%
# Display number of rows, number of columns.

### YOUR CODE HERE ###

# %% [markdown]
# <details>
# <summary><h4><strong>Pista 1</strong></h4></summary>
#
# DataFrames en `pandas` tienen un atributo que puede ser llamado para obtener el número de filas y columnas como una tupla.
# </details>

# %% [markdown]
# <details>
# <summary><h4><strong>Pista 2</strong></h4></summary>
#
# Puedes llamar al atributo `shape`.
# </details>

# %% [markdown]
# **Pregunta:** ¿Qué observas acerca del número de filas y el número de columnas en los datos?

# %% [markdown]
# [Escribe tu respuesta aquí. Haz doble clic (o presiona enter) para editar.]

# %% [markdown]
# Ahora, muestra todos los nombres de columna para tener una idea de los tipos de metadatos disponibles sobre cada jugador. Usa la propiedad columns en pandas.

# %%
# Display all column names.

### YOUR CODE HERE ###

# %% [markdown]
# La siguiente tabla proporciona una descripción de los datos en cada columna. Estos metadatos provienen de la fuente de datos, que se encuentra en la sección de referencias de este laboratorio.
#
# <center>
#
# |Nombre de la columna|Descripción de la columna|
# |:---|:-------|
# |`name`|Nombre del jugador de la NBA|
# |`gp`|Número de partidos jugados|
# |`min`|Número de minutos jugados por partido|
# |`pts`|Promedio de puntos por partido|
# |`fgm`|Promedio de canastas de campo hechas por partido|
# |`fga`|Promedio de intentos de canastas de campo por partido|
# |`fg`|Porcentaje promedio de canastas de campo hechas por partido|
# |`3p_made`|Promedio de tiros de tres puntos hechos por partido|
# |`3pa`|Promedio de intentos de tiros de tres puntos por partido|
# |`3p`|Porcentaje promedio de tiros de tres puntos hechos por partido|
# |`ftm`|Promedio de tiros libres hechos por partido|
# |`fta`|Promedio de intentos de tiros libres por partido|
# |`ft`|Porcentaje promedio de tiros libres hechos por partido|
# |`oreb`|Promedio de rebotes ofensivos por partido|
# |`dreb`|Promedio de rebotes defensivos por partido|
# |`reb`|Promedio de rebotes por partido|
# |`ast`|Promedio de asistencias por partido|
# |`stl`|Promedio de robos por partido|
# |`blk`|Promedio de bloqueos por partido|
# |`tov`|Promedio de pérdidas por partido|
# |`target_5yrs`|1 si la duración de la carrera >= 5 años, 0 en caso contrario|
#
# </center>

# %% [markdown]
# A continuación, muestre un resumen de los datos para obtener información adicional sobre el DataFrame, incluyendo los tipos de datos en las columnas.

# %%
# Use .info() to display a summary of the DataFrame.

### YOUR CODE HERE ###

# %% [markdown]
# **Pregunta:** Basándose en las tablas anteriores, ¿cuáles columnas son numéricas y cuáles columnas son categóricas?

# %% [markdown]
# [Escribe tu respuesta aquí. Haz doble clic (o presiona enter) para editar.]

# %% [markdown]
# ### Verificación de valores faltantes

# %% [markdown]
# Ahora, revisa los datos para determinar si contienen valores faltantes. Comienza mostrando el número de valores faltantes en cada columna. Después, usa isna() para verificar si cada valor en los datos falta. Finalmente, usa sum() para agregar el número de valores faltantes por columna.

# %%
# Display the number of missing values in each column.
# Check whether each value is missing.
#Aggregate the number of missing values per column.

### YOUR CODE HERE ###

# %% [markdown]
# **Pregunta:** ¿Qué observas acerca de los valores faltantes en las columnas?

# %% [markdown]
# [Escribe tu respuesta aquí. Haz doble clic (o presiona enter) para editar.]

# %% [markdown]
# **Pregunta:** ¿Por qué es importante verificar la presencia de valores faltantes?

# %% [markdown]
# Escribe tu respuesta aquí. Haz doble clic (o presiona enter) para editar.

# %% [markdown]
# ## **Paso 3: Pruebas estadísticas**

# %% [markdown]
# A continuación, utilice una técnica estadística para verificar el equilibrio de clases en los datos. Para entender qué tan equilibrado está el conjunto de datos en términos de clase, muestre el porcentaje de valores que pertenecen a cada clase en la columna objetivo. En este contexto, la clase 1 indica una duración de carrera en la NBA de al menos cinco años, mientras que la clase 0 indica una duración de carrera en la NBA de menos de cinco años.

# %%
# Display percentage (%) of values for each class (1, 0) represented in the target column of this dataset.

### YOUR CODE HERE ###

# %% [markdown]
# <details>
# <summary><h4><strong>Pista 1</strong></h4></summary>
#
# En `pandas`, `value_counts(normalize=True)` puede ser utilizado para calcular la frecuencia de cada valor distinto en una columna específica de un DataFrame.
# </details>

# %% [markdown]
# <details>
# <summary><h4><strong>Pista 2</strong></h4></summary>
#
# Después de `value_counts(normalize=True)`, multiplicar por `100` convierte las frecuencias en porcentajes (%).
# </details>

# %% [markdown]
# **Pregunta:** ¿Qué observas sobre el equilibrio de clases en la columna objetivo?

# %% [markdown]
# [Escribe tu respuesta aquí. Haz doble clic (o presiona enter) para editar.]

# %% [markdown]
# **Pregunta:** ¿Por qué es importante verificar el equilibrio de clases?

# %% [markdown]
# Escribe tu respuesta aquí. Haz doble clic (o presiona enter) para editar.

# %% [markdown]
# ## **Paso 4: Resultados y evaluación**
#
#
# Ahora, realiza ingeniería de características, con el objetivo de identificar y crear características que sirvan como predictores útiles para la variable objetivo, `target_5yrs`.

# %% [markdown]
# ### Selección de características

# %% [markdown]
# La siguiente tabla contiene descripciones de los datos en cada columna:
#
# <center>
#
# |Nombre de la columna|Descripción de la columna|
# |:---|:-------|
# |`name`|Nombre del jugador de la NBA|
# |`gp`|Número de partidos jugados|
# |`min`|Número de minutos jugados|
# |`pts`|Promedio de puntos por partido|
# |`fgm`|Promedio de tiros de campo anotados por partido|
# |`fga`|Promedio de intentos de tiros de campo por partido|
# |`fg`|Porcentaje promedio de tiros de campo anotados por partido|
# |`3p_made`|Promedio de tiros de tres puntos anotados por partido|
# |`3pa`|Promedio de intentos de tiros de tres puntos por partido|
# |`3p`|Porcentaje promedio de tiros de tres puntos anotados por partido|
# |`ftm`|Promedio de tiros libres anotados por partido|
# |`fta`|Promedio de intentos de tiros libres por partido|
# |`ft`|Porcentaje promedio de tiros libres anotados por partido|
# |`oreb`|Promedio de rebotes ofensivos por partido|
# |`dreb`|Promedio de rebotes defensivos por partido|
# |`reb`|Promedio de rebotes por partido|
# |`ast`|Promedio de asistencias por partido|
# |`stl`|Promedio de robos por partido|
# |`blk`|Promedio de bloqueos por partido|
# |`tov`|Promedio de pérdidas por partido|
# |`target_5yrs`|1 si la duración de la carrera >= 5 años, 0 en caso contrario|
#
# </center>

# %% [markdown]
# **Pregunta:** ¿Qué columnas seleccionarías y cuáles evitarías seleccionar como características, y por qué? Ten en cuenta que el objetivo es identificar características que sirvan como predictores útiles para la variable objetivo, `target_5yrs`.

# %% [markdown]
# [Escribe tu respuesta aquí. Haz doble clic (o presiona enter) para editar.]

# %% [markdown]
# A continuación, selecciona las columnas con las que deseas proceder. Asegúrate de incluir la columna objetivo, `target_5yrs`. Muestra las primeras filas para confirmar que son como se espera.

# %%
# Select the columns to proceed with and save the DataFrame in new variable `selected_data`.
# Include the target column, `target_5yrs`.

### YOUR CODE HERE ###


# Display the first few rows.

### YOUR CODE HERE ###

# %% [markdown]
# <details>
# <summary><h4><strong>Pista 1</strong></h4></summary>
#
# Consulte los materiales sobre selección de características y selección de un subconjunto de un DataFrame.
# </details>

# %% [markdown]
# <details>
# <summary><h4><strong>Pista 2</strong></h4></summary>
#
# Utilice dos pares de corchetes cuadrados, y coloque los nombres de las columnas que desea seleccionar dentro de los corchetes más internos.
#
# </details>

# %% [markdown]
# <details>
# <summary><h4><strong>Pista 3</strong></h4></summary>
#
# Hay una función en `pandas` que se puede usar para mostrar las primeras filas de un DataFrame. Asegúrate de especificar los nombres de las columnas con la ortografía que coincida con lo que hay en los datos. Usa comillas para representar cada nombre de columna como una cadena.
# </details>

# %% [markdown]
# ### Transformación de características

# %% [markdown]
# Un aspecto importante de la transformación de características es la codificación de características. Si hay columnas categóricas que deseas usar como características, esas columnas deben ser transformadas para ser numéricas. Esta técnica también se conoce como codificación de características.

# %% [markdown]
# **Pregunta:** ¿Por qué es importante considerar la transformación de características? ¿Son necesarias algunas transformaciones para las características que deseas usar?

# %% [markdown]
# [Escribe tu respuesta aquí. Haz doble clic (o presiona enter) para editar.]

# %% [markdown]
# ### Extracción de características

# %% [markdown]
# Mostrar las primeras filas que contienen descripciones de los datos para referencia. La tabla es la siguiente:
#
# <center>
#
# |Nombre de la columna|Descripción de la columna|
# |:---|:-------|
# |`name`|Nombre del jugador de la NBA|
# |`gp`|Número de partidos jugados|
# |`min`|Número de minutos jugados por partido|
# |`pts`|Promedio de puntos por partido|
# |`fgm`|Promedio de tiros de campo anotados por partido|
# |`fga`|Promedio de intentos de tiros de campo por partido|
# |`fg`|Porcentaje promedio de tiros de campo anotados por partido|
# |`3p_made`|Promedio de tiros de tres puntos anotados por partido|
# |`3pa`|Promedio de intentos de tiros de tres puntos por partido|
# |`3p`|Porcentaje promedio de tiros de tres puntos anotados por partido|
# |`ftm`|Promedio de tiros libres anotados por partido|
# |`fta`|Promedio de intentos de tiros libres por partido|
# |`ft`|Porcentaje promedio de tiros libres anotados por partido|
# |`oreb`|Promedio de rebotes ofensivos por partido|
# |`dreb`|Promedio de rebotes defensivos por partido|
# |`reb`|Promedio de rebotes por partido|
# |`ast`|Promedio de asistencias por partido|
# |`stl`|Promedio de robos por partido|
# |`blk`|Promedio de bloqueos por partido|
# |`tov`|Promedio de pérdidas por partido|
# |`target_5yrs`|1 si la duración de la carrera >= 5 años, 0 en caso contrario|
#
# </center>

# %%
# Display the first few rows of `selected_data` for reference.

### YOUR CODE HERE ###

# %% [markdown]
# **Pregunta:** ¿Qué columnas se prestan a la extracción de características?

# %% [markdown]
# [Escribe tu respuesta aquí. Haz doble clic (o presiona enter) para editar.]

# %% [markdown]
# Extrae dos características que crees que ayudarían a predecir `target_5yrs`. Luego, crea una nueva variable llamada 'extracted_data' que contenga las características de 'selected_data', así como las características que se están extrayendo.

# %%
# Extract two features that would help predict target_5yrs.
# Create a new variable named `extracted_data`.

### YOUR CODE HERE ###

# %% [markdown]
# <details>
# <summary><h4><strong>Pista 1</strong></h4></summary>
#
# Consulte los materiales sobre extracción de características.
# </details>

# %% [markdown]
# <details>
# <summary><h4><strong>Pista 2</strong></h4></summary>
#
# Utilice la función `copy()` para hacer una copia de un DataFrame. Para acceder a una columna específica de un DataFrame, utilice un par de corchetes cuadrados y coloque el nombre de la columna como una cadena dentro de los corchetes.
#
# </details>

# %% [markdown]
# <details>
# <summary><h4><strong>Pista 3</strong></h4></summary>
#
# Utiliza un par de corchetes para crear una nueva columna en un DataFrame. Las columnas en los DataFrames son objetos de series, que soportan operaciones elemento a elemento como multiplicación y división. Asegúrate de que los nombres de las columnas referenciados en tu código coincidan con la ortografía de lo que hay en el DataFrame.
# </details>

# %% [markdown]
# Ahora, para prepararse para el modelo de Naive Bayes que construirás en un laboratorio posterior, limpia los datos extraídos y asegúrate de que sean concisos. Naive Bayes implica una suposición de que las características son independientes entre sí dado la clase. Para cumplir con ese criterio, si ciertas características se agregan para obtener nuevas características, puede ser necesario eliminar esas características originales. Por lo tanto, elimina las columnas que se usaron para extraer nuevas características.
#
# **Nota:** Hay otros tipos de modelos que no implican suposiciones de independencia, por lo que esto no sería necesario en esos casos. De hecho, mantener las características originales puede ser beneficioso.

# %%
# Remove any columns from `extracted_data` that are no longer needed.

### YOUR CODE HERE ###


# Display the first few rows of `extracted_data` to ensure that column drops took place.

### YOUR CODE HERE ###

# %% [markdown]
# <details>
# <summary><h4><strong>Pista 1</strong></h4></summary>
#
# Consulte los materiales sobre extracción de características.
# </details>

# %% [markdown]
# <details>
# <summary><h4><strong>Pista 2</strong></h4></summary>
#
# Hay funciones en la biblioteca `pandas` que eliminan columnas específicas de un DataFrame y que muestran las primeras filas de un DataFrame.
# </details>

# %% [markdown]
# <details>
# <summary><h4><strong>Pista 3</strong></h4></summary>
#
# Utiliza la función `drop()` y pasa una lista con los nombres de las columnas que deseas eliminar. Por defecto, llamar a esta función resultará en un nuevo DataFrame que refleja los cambios realizados. El DataFrame original no se altera automáticamente. Puedes reasignar `extracted_data` al resultado, para actualizarlo.
#
# Utiliza la función `head()` para mostrar las primeras filas de un DataFrame.
# </details>

# %% [markdown]
# A continuación, exporta los datos extraídos como un nuevo archivo .csv. Utilizarás esto en un laboratorio posterior.

# %%
# Export the extracted data.

### YOUR CODE HERE ###

# %% [markdown]
# <details>
# <summary><h4><strong>Pista 1</strong></h4></summary>
#
# Hay una función en la biblioteca `pandas` que exporta un DataFrame como un archivo .csv.
# </details>

# %% [markdown]
# <details>
# <summary><h4><strong>Pista 2</strong></h4></summary>
#
# Utilice la función `to_csv()` para exportar el DataFrame como un archivo .csv.
# </details>

# %% [markdown]
# <details>
# <summary><h4><strong>Pista 3</strong></h4></summary>
#
# Llama a la función `to_csv()` en `extracted_data`, y pasa el nombre que deseas darle al archivo .csv resultante. Especifica el nombre del archivo como una cadena y en el nombre del archivo. Asegúrate de incluir `.csv` como la extensión del archivo. Además, pasa el parámetro `index` establecido en `0`, para que cuando ocurra la exportación, los índices de fila del DataFrame no se traten como una columna adicional en el archivo resultante.
# </details>

# %% [markdown]
# ## **Consideraciones**

# %% [markdown]
# ¿Cuáles son algunas conclusiones clave que aprendiste durante este laboratorio? Considera el proceso que seguiste y qué tareas se realizaron en cada paso, así como las prioridades importantes al entrenar datos.

# %% [markdown]
# [Escribe tu respuesta aquí. Haz doble clic (o presiona enter) para editar.]

# %% [markdown]
# ¿Qué resumen proporcionarías a las partes interesadas? Considera atributos clave que se compartirán de los datos, así como los planes futuros del proyecto.

# %% [markdown]
# [Escribe tu respuesta aquí. Haz doble clic (o presiona enter) para editar.]

# %% [markdown]
# **¡Felicidades!** Has completado este laboratorio. Sin embargo, es posible que no notes una marca de verificación verde junto a este elemento en la plataforma de Coursera. Por favor, continúa con tu progreso independientemente de la marca de verificación. Solo haz clic en el icono de "guardar" en la parte superior de este cuaderno para asegurarte de que tu trabajo ha sido registrado.
