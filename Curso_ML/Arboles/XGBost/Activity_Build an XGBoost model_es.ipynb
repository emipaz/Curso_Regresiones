# %% [markdown]
# # Actividad: Construir un modelo XGBoost

# %% [markdown]
# ## Introducción
#
# En esta actividad, construirás sobre las habilidades y técnicas que aprendiste en las lecciones de árbol de decisión y bosque aleatorio para construir tu propio modelo de clasificación XGBoost. El modelo XGBoost es una extensión muy poderosa de los árboles de decisión, por lo que tener una familiaridad sólida con este proceso fortalecerá tus habilidades y tu currículum como profesional de datos.
#
# Esta actividad es una continuación del proyecto de aerolíneas en el que construiste modelos de árbol de decisión y bosque aleatorio. Utilizarás los mismos datos, pero esta vez entrenarás, ajustarás y evaluarás un modelo XGBoost. Luego compararás el rendimiento de los tres modelos y decidirás cuál es el mejor. Finalmente, explorarás las importancias de las características de tu modelo e identificarás las características que más contribuyen a la satisfacción del cliente.

# %% [markdown]
# ## Paso 1: Importaciones

# %% [markdown]
# ### Importar paquetes
#
# Comience con sus declaraciones de importación. Primero, importe `pandas`, `numpy` y `matplotlib` para la preparación de datos. A continuación, importe scikit-learn (`sklearn`) para la preparación y evaluación del modelo. Luego, importe `xgboost`, que proporciona el algoritmo de clasificación que implementará para formular su modelo predictivo.

# %%
# Import relevant libraries and modules.

### YOUR CODE HERE ###

# %% [markdown]
# ### Cargar el conjunto de datos
#
# Para formular su modelo, `pandas` se usa para importar un csv de datos de satisfacción de pasajeros de aerolínea llamado `Invistico_Airline.csv`. Este DataFrame se llama `airline_data`. Como se muestra en esta celda, el conjunto de datos ha sido cargado automáticamente para usted. No necesita descargar el archivo .csv, ni proporcionar más código, para acceder al conjunto de datos y proceder con este laboratorio. Por favor, continúe con esta actividad completando las siguientes instrucciones.

# %%
# RUN THIS CELL TO IMPORT YOUR DATA. 

### YOUR CODE HERE ###

airline_data = pd.read_csv('Invistico_Airline.csv', error_bad_lines=False)

# %% [markdown]
# ### Mostrar los datos

# %% [markdown]
# Examine las primeras 10 filas de datos para familiarizarse con el conjunto de datos.

# %%
# Display the first ten rows of data.

### YOUR CODE HERE ###

# %% [markdown]
# ### Mostrar el tipo de datos para cada columna
#
# A continuación, observe los tipos de datos presentes en este conjunto de datos.

# %%
# Display the data type for each column in your DataFrame.

### YOUR CODE HERE ###

# %% [markdown]
# <details>
# <summary><h4><strong>Pista 1</strong></h4></summary>
#
# Recuerda los métodos para explorar DataFrames.
# </details>

# %% [markdown]
# <details>
# <summary><h4><strong>Pista 2</strong></h4></summary>
#
# Recuerda una propiedad de un DataFrame de `pandas` que te permite ver el tipo de dato de cada columna.</details>

# %% [markdown]
# <details>
# <summary><h4><strong>Pista 3</strong></h4></summary>
#
# Llama a `.dtypes` en tu DataFrame `airline_data` para ver el tipo de dato de cada columna.</details>

# %% [markdown]
# **Pregunta:** Identifique la variable objetivo (o predicha) para la satisfacción del pasajero. ¿Cuál es su hipótesis inicial sobre qué variables serán valiosas para predecir la satisfacción?

# %% [markdown]
# Escribe tu respuesta aquí. Haz doble clic (o presiona Enter) para editar.

# %% [markdown]
# ## Paso 2: Preparación del modelo
#
# Antes de proceder con la modelación, considere qué métricas querrá aprovechar en última instancia para evaluar su modelo.

# %% [markdown]
# **Pregunta:** ¿Qué métricas son las más adecuadas para evaluar este tipo de modelo?

# %% [markdown]
# Escribe tu respuesta aquí. Haz doble clic (o presiona enter) para editar.

# %% [markdown]
# ### Prepare sus datos para predicciones
#
# Es posible que haya notado al previsualizar sus datos que hay varias variables no numéricas (`tipos de datos object`) dentro del conjunto de datos.
#
# Para preparar este DataFrame para el modelado, primero convierta estas variables en un formato numérico.

# %%
# Convert the object predictor variables to numerical dummies.

### YOUR CODE HERE ###

# %% [markdown]
# <details>
# <summary><h4><strong>Pista 1</strong></h4></summary>
#
# Consulte [el contenido sobre ingeniería de características](https://www.coursera.org/learn/the-nuts-and-bolts-of-machine-learning/lecture/5mEqu/introduction-to-feature-engineering).
# </details>

# %% [markdown]
# <details>
# <summary><h4><strong>Pista 2</strong></h4></summary>
#
# Use la función `pandas` para transformar datos categóricos en variables "dummy".</details>

# %% [markdown]
# <details>
# <summary><h4><strong>Pista 3</strong></h4></summary>
#
# Utiliza la función `get_dummies()` en tu DataFrame `airline_data` para crear variables ficticias para las variables categóricas en tu conjunto de datos. Ten en cuenta que tu variable objetivo también necesitará este tratamiento.</details>

# %% [markdown]
# ### Aisla tus variables objetivo y predictoras
# Define por separado la variable objetivo (`satisfaction`) y las características.

# %%
# Define the y (target) variable.

### YOUR CODE HERE ###

# Define the X (predictor) variables.

### YOUR CODE HERE ###

# %% [markdown]
# <details>
# <summary><h4><strong>Pista 1</strong></h4></summary>
#
# Consulta [el contenido sobre dividir tus datos en x e y](https://www.coursera.org/learn/the-nuts-and-bolts-of-machine-learning/lecture/ozK9K/build-a-decision-tree-with-python).
# </details>

# %% [markdown]
# <details>
# <summary><h4><strong>Pista 2</strong></h4></summary>
#
# En `pandas`, usa corchetes `[]` para subestimar tu DataFrame especificando qué columna(s) seleccionar. Además, subestimar rápidamente un DataFrame para excluir una columna en particular usando la función `drop()` y especificando la columna a eliminar.
# </details>

# %% [markdown]
# <details>
# <summary><h4><strong>Pista 3</strong></h4></summary>
#
# En este caso, tu variable objetivo fue dividida en dos columnas a partir de la división dummy. Asegúrate de incluir solo la columna que asigna un resultado positivo (es decir, "satisfecho") como 1.
# </details>

# %% [markdown]
# ### Divide tus datos
#
# Divide tus datos en un conjunto de entrenamiento (75% de los datos) y un conjunto de prueba (25% de los datos). Este es un paso importante en el proceso, ya que te permite reservar una parte de los datos que el modelo no ha utilizado para probar qué tan bien generaliza (o funciona) el modelo en datos nuevos.

# %%
# Perform the split operation on your data.
# Assign the outputs as follows: X_train, X_test, y_train, y_test.

### YOUR CODE HERE ###

# %% [markdown]
# <details>
# <summary><h4><strong>Pista 1</strong></h4></summary>
#
# Consulte [el contenido sobre dividir sus datos entre un conjunto de entrenamiento y un conjunto de prueba](https://www.coursera.org/learn/the-nuts-and-bolts-of-machine-learning/lecture/ozK9K/build-a-decision-tree-with-python).
# </details>

# %% [markdown]
# <details>
# <summary><h4><strong>Pista 2</strong></h4></summary>
#
# Para realizar la división, llama a la función en el módulo `model_selection` de `sklearn` en las características y la variable objetivo.
# </details>

# %% [markdown]
# <details>
# <summary><h4><strong>Pista 3</strong></h4></summary>
#
# Llamar a la función `train_test_split()`, pasando tanto `features` como `target`, mientras se configura el `test_size` apropiado. Asignar la salida de esta división como `X_train`, `X_test`, `y_train`, `y_test`.
# </details>

# %% [markdown]
# ## Paso 3: Construcción del modelo

# %% [markdown]
# ### "Instanciar" tu XGBClassifer
#
# Antes de ajustar tu modelo a tu conjunto de datos de aerolínea, primero crea el modelo XGB Classifier y define su objetivo. Utilizarás este modelo para ajustar y evaluar diferentes hiperparámetros durante el proceso de validación cruzada GridSearch.

# %%
# Define xgb to be your XGBClassifier.

### YOUR CODE HERE ###

# %% [markdown]
# <details>
# <summary><h4><strong>Pista 1</strong></h4></summary>
#
# Consulte [el contenido sobre la construcción de un modelo clasificador a partir de `xgboost`](https://www.coursera.org/learn/the-nuts-and-bolts-of-machine-learning/lecture/njRAP/build-an-xgboost-model-with-python).</details>

# %% [markdown]
# <details>
# <summary><h4><strong>Pista 2</strong></h4></summary>
#
# Note que la variable objetivo en este caso es una variable binaria. </details>

# %% [markdown]
# <details>
# <summary><h4><strong>Pista 3</strong></h4></summary>
#
# Use el `XGBClassifier()` de `xgboost`. Establece el objetivo como `binary:logistic`.
# </details>

# %% [markdown]
# ### Define los parámetros para la afinación de hiperparámetros
#
# Para identificar parámetros adecuados para tu modelo `xgboost`, primero define los parámetros para la afinación de hiperparámetros. Específicamente, considera ajustar `max_depth`, `min_child_weight`, `learning_rate`, `n_estimators`, `subsample`, y/o `colsample_bytree`.
#
# Considera un rango más limitado para cada hiperparámetro para permitir una iteración y entrenamiento del modelo oportunos. Por ejemplo, usar un valor posible para cada uno de los seis hiperparámetros listados arriba tomará aproximadamente un minuto en ejecutarse en esta plataforma.
#
# ```
# {
#     'max_depth': [4],
#     'min_child_weight': [3],
#     'learning_rate': [0.1],
#     'n_estimators': [5],
#     'subsample': [0.7],
#     'colsample_bytree': [0.7]
# }
# ```
#
# Si agregas solo una opción nueva, por ejemplo cambiando `max_depth: [4]` a `max_depth: [3, 6]`, y mantienes todo lo demás igual, puedes esperar que el tiempo de ejecución se duplique aproximadamente. Si usas dos posibilidades para cada hiperparámetro, el tiempo de ejecución se extendería a ~1 hora.

# %%
# Define parameters for tuning as `cv_params`.

### YOUR CODE HERE ###

# %% [markdown]
# <details>
# <summary><h4><strong>Pista 1</strong></h4></summary>
#
# Consulte [el contenido sobre ajuste de hiperparámetros usando validación cruzada GridSearch](https://www.coursera.org/learn/the-nuts-and-bolts-of-machine-learning/lecture/afopk/tune-a-decision-tree).</details>

# %% [markdown]
# <details>
# <summary><h4><strong>Pista 2</strong></h4></summary>
#
# Considere un rango de valores para cada parámetro, similar a lo que observó en la lección. </details>

# %% [markdown]
# <details>
# <summary><h4><strong>Pista 3</strong></h4></summary>
#
# Define estos parámetros usando un diccionario de Python en el siguiente formato: `{'parámetro1': [rango, de, valores]}`</details>

# %% [markdown]
# **Pregunta:** ¿Cuál es el efecto probable de agregar más estimadores a su GridSearch?

# %% [markdown]
# Escribe tu respuesta aquí. Haz doble clic (o presiona enter) para editar.

# %% [markdown]
# ### Define cómo se evaluarán los modelos
#
# Define cómo se evaluarán los modelos para el ajuste de hiperparámetros. Para obtener la mejor comprensión del rendimiento del modelo, utilice un conjunto de métricas.

# %%
# Define your criteria as `scoring`.

### YOUR CODE HERE ###

# %% [markdown]
# <details>
# <summary><h4><strong>Pista 1</strong></h4></summary>
#
# Recuerda lo que has aprendido sobre [usar evaluación métrica](https://www.coursera.org/learn/the-nuts-and-bolts-of-machine-learning/lecture/afopk/tune-a-decision-tree) para determinar las métricas que incluyes.</details>

# %% [markdown]
# <details>
# <summary><h4><strong>Pista 2</strong></h4></summary>
#
# Considera lo que has aprendido sobre las limitaciones de incluir solo una métrica, como `accuracy`. </details>

# %% [markdown]
# <details>
# <summary><h4><strong>Pista 3</strong></h4></summary>
#
# Define métricas que equilibran los falsos positivos y falsos negativos en problemas de clasificación binaria.

# %% [markdown]
# ### Construir la validación cruzada de GridSearch
#
# Construya la validación cruzada de GridSearch usando el modelo, los parámetros y las métricas de puntuación que definió. Además, defina el número de pliegues y especifique *qué métrica* de las anteriores guiará la estrategia de refit.

# %%
# Construct your GridSearch.

### YOUR CODE HERE ###

# %% [markdown]
# <details>
# <summary><h4><strong>Pista 1</strong></h4></summary>
#
# Recuerda lo que has aprendido sobre construir un GridSearch para [validación cruzada](https://www.coursera.org/learn/the-nuts-and-bolts-of-machine-learning/lecture/W4vAW/verify-performance-using-validation).</details>

# %% [markdown]
# <details>
# <summary><h4><strong>Pista 2</strong></h4></summary>
#
# Equilibra el tiempo dedicado a la validación con el número de particiones que elijas. </details>

# %% [markdown]
# <details>
# <summary><h4><strong>Pista 3</strong></h4></summary>
#
# Elige el método de ajuste que equilibra simultáneamente los falsos positivos y los falsos negativos.

# %% [markdown]
# ### Ajustar el modelo GridSearch a tus datos de entrenamiento
#
# Si tu GridSearch tarda demasiado, revisa los rangos de parámetros anteriores y considera reducir el rango y disminuir el número de estimadores.
#
# **Nota:** La siguiente celda podría tardar varios minutos en ejecutarse.

# %%
# %%time
# fit the GridSearch model to training data

### YOUR CODE HERE ###

# %% [markdown]
# **Pregunta:** ¿Qué conjunto óptimo de parámetros produjo la búsqueda en cuadrícula?

# %% [markdown]
# Escribe tu respuesta aquí. Haz doble clic (o presiona enter) para editar.

# %% [markdown]
# <details>
# <summary><h4><strong>Pista 1</strong></h4></summary>
#
# Recuerda lo que has aprendido sobre el resultado de la búsqueda en cuadrícula.</details>

# %% [markdown]
# <details>
# <summary><h4><strong>Pista 2</strong></h4></summary>
#
# Una vez que hayas ajustado el modelo GridSearch a tus datos de entrenamiento, habrá un atributo para acceder que proporciona el conjunto de parámetros óptimo.</details>

# %% [markdown]
# <details>
# <summary><h4><strong>Pista 3</strong></h4></summary>
#
# Accede al atributo `best_params_` de tu modelo ajustado. </details>

# %% [markdown]
# ### Guarda tu modelo para referencia usando `pickle`
#
# Usa la biblioteca `pickle` que ya has importado para guardar la salida de este modelo.

# %%
# Use `pickle` to save the trained model.

### YOUR CODE HERE ###

# %% [markdown]
# <details>
# <summary><h4><strong>Pista 1</strong></h4></summary>
#
# Consulte [el contenido sobre "pickling" modelos anteriores](https://www.coursera.org/learn/the-nuts-and-bolts-of-machine-learning/lecture/FSnam/build-and-validate-a-random-forest-model-using-a-validation-data-set).</details>

# %% [markdown]
# <details>
# <summary><h4><strong>Pista 2</strong></h4></summary>
#
# El modelo a ser guardado en archivo es el modelo ajustado de GridSearch de arriba. </details>

# %% [markdown]
# <details>
# <summary><h4><strong>Pista 3</strong></h4></summary>
#
# Llamar a `pickle.dump()`, hacer referencia al modelo GridSearch ajustado y proporcionar un nombre para el archivo pickle.

# %% [markdown]
# ## Paso 4: Resultados y evaluación
#
# ### Formular predicciones en su conjunto de prueba
#
# Para evaluar las predicciones generadas por su modelo, utilice una serie de métricas y técnicas de evaluación de scikit-learn examinando los valores observados reales en el conjunto de prueba en relación con la predicción de su modelo.
#
# Primero, utilice su modelo entrenado para formular predicciones en su conjunto de prueba.

# %%
# Apply your model to predict on your test data. Call this output "y_pred".

### YOUR CODE HERE ###

# %% [markdown]
# <details>
# <summary><h4><strong>Pista 1</strong></h4></summary>
#
# Recuerda lo que has aprendido sobre crear predicciones a partir de modelos entrenados.</details>

# %% [markdown]
# <details>
# <summary><h4><strong>Pista 2</strong></h4></summary>
#
# Use el modelo GridSearch ajustado de su conjunto de entrenamiento y prediga las variables predictoras que reservó en la división entrenamiento-prueba.</details>

# %% [markdown]
# <details>
# <summary><h4><strong>Pista 3</strong></h4></summary>
#
# Llama a `predict()` en tu modelo ajustado y referencia `X_test` para crear estas predicciones.
# </details>

# %% [markdown]
# ### Aprovechar métricas para evaluar el rendimiento de tu modelo
#
# Aplica una serie de métricas de scikit-learn para evaluar tu modelo. Específicamente, imprime la puntuación de precisión, puntuación de precisión, puntuación de recuperación y puntuación f1 asociadas a tus datos de prueba y valores predichos.

# %%
# 1. Print your accuracy score.

### YOUR CODE HERE ###

# 2. Print your precision score.

### YOUR CODE HERE ###

# 3. Print your recall score.

### YOUR CODE HERE ###

# 4. Print your f1 score.

### YOUR CODE HERE ###

# %% [markdown]
# <details>
# <summary><h4><strong>Pista 1</strong></h4></summary>
#
# Consulte [el contenido sobre evaluación de modelos para obtener detalles sobre estas métricas](https://www.coursera.org/learn/the-nuts-and-bolts-of-machine-learning/lecture/njRAP/build-an-xgboost-model-with-python).
# </details>

# %% [markdown]
# <details>
# <summary><h4><strong>Pista 2</strong></h4></summary>
#
# Utilice la función en el módulo `metrics` en `sklearn` para calcular cada una de estas métricas.
# </details>

# %% [markdown]
# <details>
# <summary><h4><strong>Pista 3</strong></h4></summary>
#
# Llamar a `accuracy_score()`, `precision_score()`, `recall_score()`, y `f1_score()`, pasando `y_test` y `y_pred` en cada uno.
# </details>

# %% [markdown]
# **Pregunta:** ¿Cómo deberías interpretar tu puntuación de precisión?

# %% [markdown]
# Escribe tu respuesta aquí. Haz doble clic (o presiona enter) para editar.

# %% [markdown]
# **Pregunta:** ¿Es tu puntuación de precisión suficiente por sí sola para evaluar tu modelo?

# %% [markdown]
# Escribe tu respuesta aquí. Haz doble clic (o presiona Enter) para editar.

# %% [markdown]
# **Pregunta:** Cuando observas las puntuaciones de precisión y recall de tu modelo, ¿cómo interpretas estos valores, y uno es más preciso que el otro?

# %% [markdown]
# Escribe tu respuesta aquí. Haz doble clic (o presiona Enter) para editar.

# %% [markdown]
# **Pregunta:** ¿Qué te dice la puntuación F1 de tu modelo, más allá de lo que proporcionan las otras métricas?*

# %% [markdown]
# Escribe tu respuesta aquí. Haz doble clic (o presiona enter) para editar.

# %% [markdown]
# ### Claridad con la matriz de confusión
#
# Recuerda que una **matriz de confusión** es un gráfico que muestra los verdaderos positivos y falsos positivos y los verdaderos negativos y falsos negativos de un modelo. Ayuda a crear una representación visual de los componentes que alimentan las métricas anteriores.
#
# Crea una matriz de confusión basada en tus valores predichos para el conjunto de prueba.

# %%
# Construct and display your confusion matrix.

# Construct the confusion matrix for your predicted and test values.

### YOUR CODE HERE ###

# Create the display for your confusion matrix.

### YOUR CODE HERE ###

# Plot the visual in-line.

### YOUR CODE HERE ###

# %% [markdown]
# <details>
# <summary><h4><strong>Pista 1</strong></h4></summary>
#
# Consulte [el contenido sobre evaluación de modelos](https://www.coursera.org/learn/the-nuts-and-bolts-of-machine-learning/lecture/njRAP/build-an-xgboost-model-with-python).
# </details>

# %% [markdown]
# <details>
# <summary><h4><strong>Pista 2</strong></h4></summary>
#
# Utilice las funciones en el módulo `metrics` para crear una matriz de confusión.
# </details>

# %% [markdown]
# <details>
# <summary><h4><strong>Pista 3</strong></h4></summary>
#
# Llama a `confusion_matrix`, pasando `y_test` y `y_pred`. A continuación, utiliza `ConfusionMatrixDisplay()` para mostrar tu matriz de confusión.
# </details>

# %% [markdown]
# **Pregunta:** Cuando observas tu matriz de confusión, ¿qué notas? ¿Esto se correlaciona con alguno de tus otros cálculos?

# %% [markdown]
# Escribe tu respuesta aquí. Haz doble clic (o presiona Enter) para editar.

# %% [markdown]
# ### Visualizar las características más importantes
#
# `xgboost` tiene una función incorporada para visualizar la importancia relativa de las características en el modelo usando `matplotlib`. Salida y examina la importancia de las características de tu modelo.

# %%
# Plot the relative feature importance of the predictor variables in your model.

### YOUR CODE HERE ###

# %% [markdown]
# <details>
# <summary><h4><strong>Pista 1</strong></h4></summary>
#
# Recuerda los atributos que se proporcionan una vez que el modelo está ajustado a los datos de entrenamiento.</details>

# %% [markdown]
# <details>
# <summary><h4><strong>Pista 2</strong></h4></summary>
#
# Examine el atributo `best_estimator_` de su modelo ajustado.</details>

# %% [markdown]
# <details>
# <summary><h4><strong>Pista 3</strong></h4></summary>
#
# Para visualizar fácilmente la importancia de las características, llama a la función incorporada `plot_importance` que ofrece `xgboost` en el `best_estimator_`.</details>

# %% [markdown]
# **Pregunta:** Examine la salida de importancias de las características anterior. ¿Cuál es su evaluación del resultado? ¿Algo le sorprendió?

# %% [markdown]
# Escribe tu respuesta aquí. Haz doble clic (o presiona Enter) para editar.

# %% [markdown]
# ### Comparar modelos
#
# Crear una tabla de resultados para comparar el rendimiento del modelo.

# %%
# Create a table of results to compare model performance.

### YOUR CODE HERE ###

# %% [markdown]
# <details>
# <summary><h4><strong>Pista 1</strong></h4></summary>
#
# Crear un DataFrame y usar la función `pd.DataFrame()`.
#
# </details>

# %% [markdown]
# **Pregunta:** ¿Cómo se compara este modelo con los modelos de árbol de decisión y bosque aleatorio que construiste en laboratorios anteriores?

# %% [markdown]
# Escribe tu respuesta aquí. Haz doble clic (o presiona Enter) para editar.

# %% [markdown]
# ## Consideraciones
#
# **¿Cuáles son algunas conclusiones clave que aprendiste de este laboratorio?**
#
# [Escribe tu respuesta aquí. Haz doble clic (o presiona Enter) para editar.]
#
# **¿Cómo compartirías tus hallazgos con tu equipo?**
#
# [Escribe tu respuesta aquí. Haz doble clic (o presiona Enter) para editar.]
#
# **¿Qué compartirías y recomendarías a las partes interesadas?**
#
# [Escribe tu respuesta aquí. Haz doble clic (o presiona Enter) para editar.]

# %% [markdown]
# ¡Felicidades! Has completado este laboratorio. Sin embargo, es posible que no notes una marca de verificación verde junto a este elemento en la plataforma de Coursera. Por favor, continúa con tu progreso independientemente de la marca de verificación. Solo haz clic en el icono de "guardar" en la parte superior de este cuaderno para asegurarte de que tu trabajo ha sido registrado
