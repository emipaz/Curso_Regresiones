# %% [markdown]
# # Actividad: Pruebas de hipótesis con Python

# %% [markdown]
# ## **Introducción**

# %% [markdown]
# Como has estado aprendiendo, el análisis de varianza (comúnmente llamado ANOVA) es un conjunto de técnicas estadísticas que prueban la diferencia de medias entre tres o más grupos. Es una herramienta poderosa para determinar si las medias de la población son diferentes entre grupos y para responder a una amplia gama de preguntas empresariales.
#
# En esta actividad, eres un profesional de datos que trabaja con datos históricos de promociones de marketing. Utilizarás los datos para realizar un ANOVA de una vía y una prueba post hoc de ANOVA. Luego, comunicarás tus resultados a las partes interesadas. Estas experiencias te ayudarán a hacer recomendaciones con mayor confianza en un entorno profesional.
#
# En tu conjunto de datos, cada fila corresponde a una promoción de marketing independiente, donde tu negocio utiliza promociones en TV, redes sociales, radio e influencers para aumentar las ventas. Anteriormente, has proporcionado ideas sobre cómo diferentes tipos de promociones afectan las ventas; ahora, las partes interesadas quieren saber si las ventas son significativamente diferentes entre varios tipos de promociones en TV e influencers.
#
# Para abordar esta solicitud, una prueba de ANOVA de una vía te permitirá determinar si existe una diferencia estadísticamente significativa en las ventas entre grupos. Esto incluye:
# * Utilizar gráficos y estadísticas descriptivas para seleccionar una variable independiente categórica
# * Crear y ajustar un modelo de regresión lineal con la variable independiente categórica seleccionada
# * Verificar las suposiciones del modelo
# * Realizar e interpretar una prueba de ANOVA de una vía
# * Comparar pares de grupos usando una prueba post hoc de ANOVA
# * Interpretar las salidas del modelo y comunicar los resultados a partes interesadas no técnicas

# %% [markdown]
# ## **Paso 1: Importaciones**

# %% [markdown]
# Importar pandas, pyplot de matplotlib, seaborn, api de statsmodels, ols de statsmodels.formula.api, y pairwise_tukeyhsd de statsmodels.stats.multicomp.

# %%
# Import libraries and packages.

### YOUR CODE HERE ###

# %% [markdown]
# `Pandas` fue utilizado para cargar el conjunto de datos `marketing_sales_data.csv` como `data`, ahora muestre las primeras cinco filas. Las variables en el conjunto de datos han sido ajustadas para adaptarse a los objetivos de este laboratorio. Como se muestra en esta celda, el conjunto de datos ha sido cargado automáticamente para usted. No necesita descargar el archivo .csv, ni proporcionar más código, para acceder al conjunto de datos y proceder con este laboratorio. Por favor, continúe con esta actividad completando las siguientes instrucciones.

# %%
# RUN THIS CELL TO IMPORT YOUR DATA.

### YOUR CODE HERE ### 
data = pd.read_csv('marketing_sales_data.csv')

# Display the first five rows.

### YOUR CODE HERE ###

# %% [markdown]
# Las características en los datos son:
# * Presupuesto de promoción en TV (en categorías Baja, Media y Alta)
# * Presupuesto de promoción en redes sociales (en millones de dólares)
# * Presupuesto de promoción en radio (en millones de dólares)
# * Ventas (en millones de dólares)
# * Tamaño del influencer (en categorías Mega, Macro, Nano y Micro)

# %% [markdown]
# **Pregunta:** ¿Por qué es útil realizar un análisis exploratorio de datos antes de construir un modelo de regresión lineal?

# %% [markdown]
# Escribe tu respuesta aquí. Haz doble clic (o presiona Enter) para editar.

# %% [markdown]
# ## **Paso 2: exploración de datos**

# %% [markdown]
# Primero, usa un diagrama de caja para determinar cómo varía `Ventas` en función de la categoría de presupuesto de promoción `TV`.

# %%
# Create a boxplot with TV and Sales.

### YOUR CODE HERE ###

# %% [markdown]
# <details>
# <summary><h4><strong>Pista 1</strong></h4></summary>
#
# Hay una función en la biblioteca `seaborn` que crea un diagrama de caja que muestra la distribución de una variable a través de múltiples grupos.
#
# </details>

# %% [markdown]
# <details>
# <summary><h4><strong>Pista 2</strong></h4></summary>
#
# Utilice la función `boxplot()` de `seaborn`.
#
# </details>

# %% [markdown]
# <details>
# <summary><h4><strong>Pista 3</strong></h4></summary>
#
# Use `TV` como el argumento `x`, `Sales` como el argumento `y`, y `data` como el argumento `data`.
#
# </details>

# %% [markdown]
# **Pregunta:** ¿Hay variación en `Ventas` basada en el presupuesto de promoción de `TV`?

# %% [markdown]
# Escribe tu respuesta aquí. Haz doble clic (o presiona Enter) para editar.

# %% [markdown]
# Ahora, usa un diagrama de caja para determinar cómo varía `Ventas` según la categoría de tamaño de `Influencer`.

# %%
# Create a boxplot with Influencer and Sales.

### YOUR CODE HERE ###

# %% [markdown]
# **Pregunta:** ¿Hay variación en `Ventas` según el tamaño del `Influencer`?

# %% [markdown]
# Escribe tu respuesta aquí. Haz doble clic (o presiona enter) para editar.

# %% [markdown]
# ### Eliminar datos faltantes
#
# Puede recordar de laboratorios anteriores que este conjunto de datos contiene filas con valores faltantes. Para corregir esto, elimine estas filas. Luego, confirme que los datos no contienen valores faltantes.

# %%
# Drop rows that contain missing data and update the DataFrame.

### YOUR CODE HERE ### 


# Confirm the data contains no missing values.

### YOUR CODE HERE ###

# %% [markdown]
# <details>
# <summary><h4><strong>Pista 1</strong></h4></summary>
#
# Hay una función de `pandas` que elimina valores faltantes.
#
# </details>

# %% [markdown]
# <details>
# <summary><h4><strong>Pista 2</strong></h4></summary>
#
# La función `dropna()` elimina los valores faltantes de un objeto (por ejemplo, DataFrame).
#
# </details>

# %% [markdown]
# <details>
# <summary><h4><strong>Pista 3</strong></h4></summary>
#
# Verifica que los datos estén actualizados correctamente después de eliminar las filas que contienen datos faltantes.
#
# </details>

# %% [markdown]
# ## **Paso 3: Construcción del modelo**

# %% [markdown]
# Ajusta un modelo de regresión lineal que predice `Sales` usando una de las variables categóricas independientes en `data`. Consulta tu código anterior para definir y ajustar un modelo de regresión lineal.

# %%
# Define the OLS formula.

### YOUR CODE HERE ### 


# Create an OLS model.

### YOUR CODE HERE ### 


# Fit the model.

### YOUR CODE HERE ### 


# Save the results summary.

### YOUR CODE HERE ### 


# Display the model results.

### YOUR CODE HERE ###

# %% [markdown]
# <details>
# <summary><h4><strong>Pista 1</strong></h4></summary>
#
# Refiere al código que has escrito para ajustar modelos de regresión lineal.
#
# </details>

# %% [markdown]
# <details>
# <summary><h4><strong>Pista 2</strong></h4></summary>
#
# Utiliza la función `ols()` de `statsmodels.formula.api`, que crea un modelo a partir de una fórmula y un DataFrame, para crear un modelo OLS.
#
# </details>

# %% [markdown]
# <details>
# <summary><h4><strong>Pista 3</strong></h4></summary>
#
# Use `C()` alrededor del nombre de la variable en la fórmula ols para indicar que una variable es categórica.
#
# Asegúrate de que los nombres de las cadenas de variables coincidan exactamente con los nombres de las columnas en `data`.
#
# </details>

# %% [markdown]
# **Pregunta:** ¿Qué variable categórica elegiste para el modelo? ¿Por qué?

# %% [markdown]
# Escribe tu respuesta aquí. Haz doble clic (o presiona enter) para editar.

# %% [markdown]
# ### Verificar las suposiciones del modelo

# %% [markdown]
# Ahora, verifica que las cuatro suposiciones de regresión lineal se mantengan para tu modelo.

# %% [markdown]
# **Pregunta:** ¿Se cumple la suposición de linealidad?

# %% [markdown]
# Escribe tu respuesta aquí. Haz doble clic (o presiona Enter) para editar.

# %% [markdown]
# La suposición de observación independiente establece que cada observación en el conjunto de datos es independiente. Como cada promoción de marketing ( fila) es independiente de las demás, la suposición de independencia no se viola.

# %% [markdown]
# A continuación, verifica que se cumple la suposición de normalidad para el modelo.

# %%
# Calculate the residuals.

### YOUR CODE HERE ### 


# Create a histogram with the residuals. 

### YOUR CODE HERE ### 


# Create a QQ plot of the residuals.

### YOUR CODE HERE ###

# %% [markdown]
# <details>
# <summary><h4><strong>Pista 1</strong></h4></summary>
#
# Accede a los residuos del objeto del modelo ajustado.
#
# </details>

# %% [markdown]
# <details>
# <summary><h4><strong>Pista 2</strong></h4></summary>
#
# Use `model.resid` para obtener los residuos de un modelo ajustado llamado `model`.
#
# </details>

# %% [markdown]
# <details>
# <summary><h4><strong>Pista 3</strong></h4></summary>
#
# Para el histograma, pasa los residuos como el primer argumento en la función `seaborn` `histplot()`.
#
# Para el gráfico QQ, pasa los residuos como el primer argumento en la función `statsmodels` `qqplot()`.
#
# </details>

# %% [markdown]
# **Pregunta:** ¿Se cumple la suposición de normalidad?

# %% [markdown]
# Escribe tu respuesta aquí. Haz doble clic (o presiona Enter) para editar.

# %% [markdown]
# Ahora, verificar que se cumple la suposición de varianza constante (homocedasticidad) para este modelo.

# %%
# Create a scatter plot with the fitted values from the model and the residuals.

### YOUR CODE HERE ### 


# Add a line at y = 0 to visualize the variance of residuals above and below 0.

### YOUR CODE HERE ###

# %% [markdown]
# <details>
# <summary><h4><strong>Pista 1</strong></h4></summary>
#
# Accede a los valores ajustados del objeto modelo ajustado anteriormente.
#
# </details>

# %% [markdown]
# <details>
# <summary><h4><strong>Pista 2</strong></h4></summary>
#
# Use `model.fittedvalues` para obtener los valores ajustados del modelo ajustado llamado `model`.
#
# </details>

# %% [markdown]
# <details>
# <summary><h4><strong>Pista 3</strong></h4></summary>
#
#
# Llamar a la función `scatterplot()` de la biblioteca `seaborn` y pasar los valores ajustados y los residuos.
#
# Agregar una línea a una figura usando la función `axline()`.
#
# </details>

# %% [markdown]
# **Pregunta:** ¿Se cumple la suposición de varianza constante (homocedasticidad)?

# %% [markdown]
# Escribe tu respuesta aquí. Haz doble clic (o presiona Enter) para editar.

# %% [markdown]
# ## **Paso 4: Resultados y evaluación**

# %% [markdown]
# Primero, muestre los resultados de la regresión OLS.

# %%
# Display the model results summary.

### YOUR CODE HERE ###

# %% [markdown]
# **Pregunta:** ¿Cuál es tu interpretación del R-cuadrado del modelo?

# %% [markdown]
# Escribe tu respuesta aquí. Haz doble clic (o presiona enter) para editar.

# %% [markdown]
# **Pregunta:** ¿Cuál es tu interpretación de las estimaciones de los coeficientes? ¿Son estadísticamente significativos los coeficientes?

# %% [markdown]
# Escribe tu respuesta aquí. Haz doble clic (o presiona Enter) para editar.

# %% [markdown]
# **Pregunta:** ¿Crees que tu modelo podría mejorarse? ¿Por qué o por qué no? ¿Cómo?

# %% [markdown]
# Escribe tu respuesta aquí. Haz doble clic (o presiona Enter) para editar.

# %% [markdown]
# ### Realizar una prueba de ANOVA de una vía
#
# Con el modelo ajustado, ejecute una prueba de ANOVA de una vía para determinar si existe una diferencia estadísticamente significativa en `Sales` entre los grupos.

# %%
# Create an one-way ANOVA table for the fit model.

### YOUR CODE HERE ###

# %% [markdown]
# <details>
# <summary><h4><strong>Pista 1</strong></h4></summary>
#
# Revisa lo que has aprendido sobre cómo realizar una prueba de ANOVA de una vía.
#
# </details>

# %% [markdown]
# <details>
# <summary><h4><strong>Pista 2</strong></h4></summary>
#
# Hay una función en `statsmodels.api` (es decir, `sm`) que realiza una prueba de ANOVA para un modelo lineal ajustado.
#
# </details>

# %% [markdown]
# <details>
# <summary><h4><strong>Pista 3</strong></h4></summary>
#
# Utilice la función `anova_lm()` de `sm.stats`. Especifique el tipo de prueba ANOVA (por ejemplo, de una vía o de dos vías), usando el parámetro `typ`.
#
#
# </details>

# %% [markdown]
# **Pregunta:** ¿Cuáles son las hipótesis nula y alternativa para la prueba ANOVA?

# %% [markdown]
# Escribe tu respuesta aquí. Haz doble clic (o presiona Enter) para editar.

# %% [markdown]
# **Pregunta:** ¿Cuál es tu conclusión del test de ANOVA de una vía?

# %% [markdown]
# Escribe tu respuesta aquí. Haz doble clic (o presiona Enter) para editar.

# %% [markdown]
# **Pregunta:** ¿Qué te dijo la prueba ANOVA?

# %% [markdown]
# Escribe tu respuesta aquí. Haz doble clic (o presiona Enter) para editar.

# %% [markdown]
# ### Realizar una prueba post hoc de ANOVA
#
# Si tienes resultados significativos de la prueba de ANOVA de una vía, puedes aplicar pruebas post hoc de ANOVA como la prueba HSD de Tukey.
#
# Ejecuta la prueba HSD de Tukey para comparar si hay una diferencia significativa entre cada par de categorías para TV.

# %%
# Perform the Tukey's HSD post hoc test.

### YOUR CODE HERE ###

# %% [markdown]
# <details>
# <summary><h4><strong>Pista 1</strong></h4></summary>
#
# Revisa lo que has aprendido sobre cómo realizar una prueba post hoc de Tukey's HSD.
#
# </details>

# %% [markdown]
# <details>
# <summary><h4><strong>Pista 2</strong></h4></summary>
#
# Utilice la función `pairwise_tukeyhsd()` de `statsmodels.stats.multicomp`.
#
# </details>

# %% [markdown]
# <details>
# <summary><h4><strong>Pista 3</strong></h4></summary>
#
# El argumento `endog` en `pairwise_tukeyhsd` indica qué variable se está comparando entre grupos (es decir, `Sales`). El argumento `groups` en `pairwise_tukeyhsd` le dice a la función qué variable contiene el grupo que te interesa revisar.
#
# </details>

# %% [markdown]
# **Pregunta:** ¿Cuál es tu interpretación de la prueba Tukey HSD?

# %% [markdown]
# Escribe tu respuesta aquí. Haz doble clic (o presiona Enter) para editar.

# %% [markdown]
# **Pregunta:** ¿Qué te dijo el post hoc?

# %% [markdown]
# Escribe tu respuesta aquí. Haz doble clic (o presiona Enter) para editar.

# %% [markdown]
# ## **Consideraciones**
#
# **¿Cuáles son algunas ideas clave que aprendiste durante este laboratorio?**
#
# [Escribe tu respuesta aquí. Haz doble clic (o presiona Enter) para editar.]
#
# **¿Qué resumen proporcionarías a las partes interesadas? Considera la significancia estadística de las relaciones clave y las diferencias en la distribución.**
#
# [Escribe tu respuesta aquí. Haz doble clic (o presiona Enter) para editar.]

# %% [markdown]
# #### **Referencia**
# [Saragih, H.S. *Datos ficticios de marketing y ventas*](https://www.kaggle.com/datasets/harrimansaragih/dummy-advertising-and-sales-data)

# %% [markdown]
# **¡Felicidades!** Has completado este laboratorio. Sin embargo, es posible que no notes una marca de verificación verde junto a este elemento en la plataforma de Coursera. Por favor, continúa con tu progreso independientemente de la marca de verificación. Solo haz clic en el icono de "guardar" en la parte superior de este cuaderno para asegurarte de que tu trabajo ha sido registrado.
