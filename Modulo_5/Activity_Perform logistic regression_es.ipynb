# %% [markdown]
# # Activity: Realizar regresión logística
#
# ## Introducción
#
# En esta actividad, completarás una regresión logística binomial efectiva. Este ejercicio te ayudará a entender mejor el valor de usar regresión logística para hacer predicciones de una variable dependiente basada en una variable independiente y te ayudará a ganar confianza en la práctica de la regresión logística. Debido a que la regresión logística se utiliza en una amplia variedad de industrias, volverte competente en este proceso te ayudará a ampliar tu conjunto de habilidades de manera ampliamente aplicable.
#
# Para esta actividad, trabajas como consultor para una aerolínea. La aerolínea está interesada en saber si una mejor experiencia de entretenimiento a bordo conduce a una mayor satisfacción del cliente. Quieren que construyas y evalúes un modelo que prediga si un cliente futuro estaría satisfecho con sus servicios dado el feedback previo del cliente sobre su experiencia de vuelo.
#
# Los datos para esta actividad son para un tamaño de muestra de 129,880 clientes. Incluyen puntos de datos como clase, distancia del vuelo y entretenimiento a bordo, entre otros. Tu objetivo será utilizar un modelo de regresión logística binomial para ayudar a la aerolínea a modelar y entender mejor estos datos.
#
# Debido a que esta actividad utiliza un conjunto de datos de la industria, necesitarás realizar un análisis exploratorio de datos básico, limpieza de datos y otras manipulaciones para preparar los datos para el modelado.
#
# En esta actividad, practicarás las siguientes habilidades:
#
# * Importar paquetes y cargar datos
# * Explorar los datos y completar el proceso de limpieza
# * Construir un modelo de regresión logística binomial
# * Evaluar un modelo de regresión logística binomial usando una matriz de confusión

# %% [markdown]
# ## Paso 1: Importaciones
#
# ### Importar paquetes
#
# Importar paquetes relevantes de Python. Utilice `train_test_split`, `LogisticRegression`, y varias importaciones de `sklearn.metrics` para construir, visualizar y evaluar el modelo.

# %%
### YOUR CODE HERE ###

# Standard operational package imports.

# Important imports for preprocessing, modeling, and evaluation.

# Visualization package imports.

# %% [markdown]
# ### Cargar el conjunto de datos

# %% [markdown]
# El conjunto de datos **Invistico_Airline.csv** ha sido cargado. El DataFrame de pandas resultante se guarda como una variable llamada `df_original`. Como se muestra en esta celda, el conjunto de datos ha sido cargado automáticamente para ti. No necesitas descargar el archivo .csv, ni proporcionar más código, para acceder al conjunto de datos y continuar con este laboratorio. Por favor, continúa con esta actividad completando las siguientes instrucciones.

# %%
# RUN THIS CELL TO IMPORT YOUR DATA.

### YOUR CODE HERE ###
df_original = pd.read_csv("Invistico_Airline.csv")

# %% [markdown]
# <details>
#   <summary><h4><strong>Pista 1</strong></h4></summary>
#
# Utiliza una función de la biblioteca pandas para leer el archivo csv.
#
# </details>

# %% [markdown]
# <details>
#   <summary><h4><strong>Pista 2</strong></h4></summary>
#
# Utilice la función `read_csv` y pase el nombre del archivo como una cadena de texto.
#
# </details>

# %% [markdown]
# <details>
#   <summary><h4><strong>Pista 3</strong></h4></summary>
#
# Utilice `pd.read_csv("insertarnombredearchivoaqui")`.
#
# </details>

# %% [markdown]
# ### Mostrar las primeras 10 filas
#
# Mostrar las primeras 10 filas de datos.

# %%
### YOUR CODE HERE ###

# %% [markdown]
# <details>
#   <summary><h4><strong>Pista 1</strong></h4></summary>
#
# Utiliza la función `head()`.
#
# </details>

# %% [markdown]
# <details>
#   <summary><h4><strong>Pista 2</strong></h4></summary>
#
# Si solo se muestran cinco filas, es porque la función por defecto devuelve cinco filas. Para cambiar esto, especifica cuántas filas `(n = )` quieres mostrar.
#
# </details>

# %% [markdown]
# ## Paso 2: Exploración de datos, limpieza de datos y preparación del modelo
#
# ### Preparar los datos
#
# Después de cargar el conjunto de datos, prepare los datos para que sean adecuados para un modelo de regresión logística. Esto incluye:
#
# * Explorar los datos
# * Verificar valores faltantes
# * Codificar los datos
# * Renombrar una columna
# * Crear los datos de entrenamiento y prueba

# %% [markdown]
# ### Explora los datos
#
# Verifica el tipo de datos de cada columna. Ten en cuenta que los modelos de regresión logística esperan datos numéricos.

# %%
### YOUR CODE HERE ###

# %% [markdown]
# <details>
#   <summary><h4><strong>Pista 1</strong></h4></summary>
#
# Utilice el atributo `dtypes` en el DataFrame.
#
# </details>

# %% [markdown]
# ### Verifique el número de clientes satisfechos en el conjunto de datos
#
# Para predecir la satisfacción del cliente, verifique cuántos clientes en el conjunto de datos están satisfechos antes de modelar.

# %%
### YOUR CODE HERE ###

# %% [markdown]
# <details>
#   <summary><h4><strong>Pista 1</strong></h4></summary>
#
# Utiliza una función de la biblioteca pandas que devuelve una serie de pandas que contiene conteos de valores únicos.
#
# </details>

# %% [markdown]
# <details>
#   <summary><h4><strong>Pista 2</strong></h4></summary>
#
# Utilice la función `value_counts()`. Para examinar cuántos valores NaN hay, configure el parámetro `dropna` pasado a esta función en `False`.
#
# </details>

# %% [markdown]
# **Pregunta:** ¿Cuántos clientes satisfechos y insatisfechos hubo?

# %% [markdown]
# Escribe tu respuesta aquí. Haz doble clic (o presiona Enter) para editar.

# %% [markdown]
# **Pregunta:** ¿Qué porcentaje de clientes estaban satisfechos?

# %% [markdown]
# Escribe tu respuesta aquí. Haz doble clic (o presiona Enter) para editar.

# %% [markdown]
# ### Verificar valores faltantes

# %% [markdown]
# Una suposición de los modelos de regresión logística es que no hay valores faltantes. Verifique si hay valores faltantes en las filas de los datos.

# %%
### YOUR CODE HERE ###

# %% [markdown]
# <details>
#   <summary><h4><strong>Pista 1</strong></h4></summary>
#
# Para obtener el número de filas en los datos con valores faltantes, usa la función `isnull` seguida de la función `sum`.
#
# </details>

# %% [markdown]
# **Pregunta:** ¿Deberías eliminar las filas donde la columna `Retraso en la llegada en minutos` tiene valores faltantes, aunque la aerolínea esté más interesada en la columna `entretenimiento a bordo`?

# %% [markdown]
# Escribe tu respuesta aquí. Haz doble clic (o presiona Enter) para editar.

# %% [markdown]
# ### Eliminar las filas con valores faltantes
#
# Elimina las filas con valores faltantes y guarda el DataFrame de pandas resultante en una variable llamada `df_subset`.

# %%
### YOUR CODE HERE ###

# %% [markdown]
# <details>
#   <summary><h4><strong>Pista 1</strong></h4></summary>
#
# Utilice la función `dropna`.
#
# </details>

# %% [markdown]
# <details>
#   <summary><h4><strong>Pista 2</strong></h4></summary>
#
# Establece el parámetro axis pasado a la función `dropna` a `0` si quieres eliminar filas que contienen valores faltantes, o `1` si quieres eliminar columnas que contienen valores faltantes. Opcionalmente, usa reset_index para evitar una advertencia de SettingWithCopy más adelante en el cuaderno.
#
# </details>

# %% [markdown]
# ### Preparar los datos
#
# Si quieres crear un gráfico (`sns.regplot`) de tu modelo para visualizar los resultados más tarde en el cuaderno, la variable independiente `Entretenimiento a bordo` no puede ser "de tipo int" y la variable dependiente `satisfacción` no puede ser "de tipo objeto."
#
# Haz que la columna `Entretenimiento a bordo` sea "de tipo float."

# %%
### YOUR CODE HERE ###

# %% [markdown]
# <details>
#
#   <summary><h4><strong>Pista 1</strong></h4></summary>
# Utiliza la función `.astype()` con el diccionario `{"Entretenimiento a bordo": float}` como entrada.
#
# </details>

# %% [markdown]
# ### Convertir la columna categórica `satisfaction` en numérica
#
# Convertir la columna categórica `satisfaction` en numérica mediante codificación one-hot.

# %%
### YOUR CODE HERE ###

# %% [markdown]
# <details>
#   <summary><h4><strong>Pista 1</strong></h4></summary>
#
# Use `OneHotEncoder()` de `sklearn.preprocessing`.
# </details>

# %% [markdown]
# <details>
#   <summary><h4><strong>Pista 2</strong></h4></summary>
#
# Llamar a `OneHotEncoder()`, especificando el argumento `drop` como `'first'` para eliminar columnas redundantes del resultado.
#
# Llamar a `.fit_transform()`, pasando el subconjunto de los datos que deseas codificar (el subconjunto que consiste en `satisfaction`).
#
# Llamar a `.toarray()` para convertir la matriz dispersa que devuelve `.fit_transform()` en un array.
#
# </details>

# %% [markdown]
# <details>
#   <summary><h4><strong>Pista 3</strong></h4></summary>
#
# Index `df_subset` con un doble par de corchetes para obtener un DataFrame que consiste solo en `satisfaction`.
#
# Después de obtener los valores codificados, actualiza la columna `satisfaction` (puedes usar reasignación).
#
# </details>

# %% [markdown]
# ### Muestra las primeras 10 filas de `df_subset`
#
# Para examinar qué hizo la codificación one-hot en el DataFrame, muestra las primeras 10 filas de `df_subset`.

# %%
### YOUR CODE HERE ###

# %% [markdown]
# <details>
#   <summary><h4><strong>Pista 1</strong></h4></summary>
#
# Utiliza la función `head()`.
#
# </details>

# %% [markdown]
# <details>
#   <summary><h4><strong>Pista 2</strong></h4></summary>
#
# Si solo se muestran cinco filas, es porque la función por defecto devuelve cinco filas. Para cambiar esto, especifica cuántas filas `(n = )` quieres.
#
# </details>

# %% [markdown]
# ### Crear los datos de entrenamiento y prueba
#
# Pon el 70% de los datos en un conjunto de entrenamiento y el 30% restante en un conjunto de prueba. Crear un DataFrame X y y con solo las variables necesarias.

# %%
### YOUR CODE HERE ###

# %% [markdown]
# <details>
#   <summary><h4><strong>Pista 1</strong></h4></summary>
#
# Utilice `train_test_split`.
#
# </details>

# %% [markdown]
# <details>
#   <summary><h4><strong>Pista 2</strong></h4></summary>
#
# Si nombraste tu variable independiente `X` y tu variable dependiente `y`, entonces sería `train_test_split(X, y, test_size=0.30, random_state=42)`.
#
# </details>

# %% [markdown]
# <details>
#   <summary><h4><strong>Pista 3</strong></h4></summary>
#
# Cuando uses `train_test_split`, pasa `42` a `random_state`. `random_state` se usa para que si otros profesionales de datos ejecutan este código, puedan obtener la misma división exacta de entrenamiento y prueba. Si usas un estado aleatorio diferente, tus resultados diferirán. </details>

# %% [markdown]
# **Pregunta:** Si quieres considerar la satisfacción del cliente con tu modelo, ¿deberías entrenar tu modelo para usar `entretenimiento a bordo` como tu única variable independiente?

# %% [markdown]
# Escribe tu respuesta aquí. Haz doble clic (o presiona Enter) para editar.

# %% [markdown]
# ## Paso 3: Construcción del modelo

# %% [markdown]
# ### Ajustar un modelo de regresión logística a los datos
#
# Construir un modelo de regresión logística y ajustar el modelo a los datos de entrenamiento.

# %%
### YOUR CODE HERE ###

# %% [markdown]
# <details>
#   <summary><h4><strong>Pista 1</strong></h4></summary>
#
# Utilice `LogisticRegression()` y la función `fit()` en el conjunto de entrenamiento. `LogisticRegression().fit(X_train,y_train)`.
#
# </details>

# %% [markdown]
# ### Obtener estimaciones de parámetros
# Asegúrate de mostrar los dos parámetros de tu modelo.

# %%
### YOUR CODE HERE ###

# %%
### YOUR CODE HERE ###

# %% [markdown]
# <details>
#   <summary><h4><strong>Pista 1</strong></h4></summary>
#
# Consulte el contenido sobre [obtener las estimaciones de los parámetros](https://www.coursera.org/learn/regression-analysis-simplify-complex-data-relationships/lecture/XCLzq/construct-a-logistic-regression-model-with-python) de un modelo de regresión logística.
#
# </details>

# %% [markdown]
# <details>
#   <summary><h4><strong>Pista 2</strong></h4></summary>
#
# Llamar a atributos para obtener las estimaciones del coeficiente y la intersección.
#
# </details>

# %% [markdown]
# <details>
#   <summary><h4><strong>Pista 3</strong></h4></summary>
#
# Use `.coef_` y `.intercept_`
#
# </details>

# %% [markdown]
# ### Crear un gráfico de tu modelo
#
# Crear un gráfico de tu modelo para visualizar resultados usando el paquete seaborn.

# %%
### YOUR CODE HERE ###

# %% [markdown]
# <details>
#   <summary><h4><strong>Pista 1</strong></h4></summary>
#
# Use una función de la biblioteca seaborn que puede graficar datos y un ajuste de modelo de regresión logística.
#
# </details>

# %% [markdown]
# <details>
#   <summary><h4><strong>Pista 2</strong></h4></summary>
#
# Utilice la función `regplot`.
#
# </details>

# %% [markdown]
# <details>
#   <summary><h4><strong>Pista 3</strong></h4></summary>
#
# Establezca el parámetro `logistic` pasado a esta función en `True` para estimar un modelo de regresión logística.
#
# </details>

# %% [markdown]
# **Pregunta:** ¿Qué puedes decir del gráfico?

# %% [markdown]
# Escribe tu respuesta aquí. Haz doble clic (o presiona enter) para editar.

# %% [markdown]
# ## Paso 4. Resultados y evaluación

# %% [markdown]
# ### Predecir el resultado para el conjunto de datos de prueba
#
# Ahora que has completado tu regresión, revisa y analiza tus resultados. Primero, ingresa el conjunto de datos de retención en la función `predict` para obtener las etiquetas predichas del modelo. Guarda estas predicciones como una variable llamada `y_pred`.

# %%
### YOUR CODE HERE ###

# Save predictions.

# %% [markdown]
# ### Imprimir `y_pred`
#
# Para examinar las predicciones, imprime `y_pred`.

# %%
### YOUR CODE HERE ###

# %% [markdown]
# ### Use las funciones `predict_proba` y `predict` en `X_test`

# %%
# Use predict_proba to output a probability.

### YOUR CODE HERE ###

# %% [markdown]
# <details>
#   <summary><h4><strong>Pista 1</strong></h4></summary>
#
# Usar la función `predict_proba` en `X_test` producirá la probabilidad de que cada observación sea un 0 o un 1.
#
# </details>

# %%
# Use predict to output 0's and 1's.

### YOUR CODE HERE ###

# %% [markdown]
# <details>
#   <summary><h4><strong>Pista 2</strong></h4></summary>
#
# `clf.predict` produce un arreglo de 0's y 1's, donde los 0's están insatisfechos y los 1's están satisfechos.
#
# </details>

# %% [markdown]
# ### Analizar los resultados
#
# Imprimir la precisión, precisión, recall y puntuación F1 del modelo.

# %%
### YOUR CODE HERE ###

# %% [markdown]
# <details>
#   <summary><h4><strong>Pista 1</strong></h4></summary>
#
# Use cuatro funciones diferentes de `metrics` para obtener la precisión, la exactitud, el recall y la puntuación F1.
#
# </details>

# %% [markdown]
# <details>
#   <summary><h4><strong>Pista 2</strong></h4></summary>
#
# Ingresa `y_test` y `y_pred` en las funciones `metrics.accuracy_score`, `metrics.precision_score`, `metrics.recall_score`, y `metrics.f1_score`.
#
# </details>

# %% [markdown]
# ### Produce una matriz de confusión

# %% [markdown]
# Los profesionales de datos a menudo quieren saber los tipos de errores cometidos por un algoritmo. Para obtener esta información, produce una matriz de confusión.

# %%
### YOUR CODE HERE ###

# %% [markdown]
# **Pregunta:** ¿Qué te llama la atención de la matriz de confusión?

# %% [markdown]
# Escribe tu respuesta aquí. Haz doble clic (o presiona Enter) para editar.

# %% [markdown]
# <details>
#   <summary><h4><strong>Pista 1</strong></h4></summary>
#
# Consulte [el contenido sobre cómo graficar una matriz de confusión](https://www.coursera.org/learn/regression-analysis-simplify-complex-data-relationships/lecture/SpRqe/evaluate-a-binomial-logistic-regression-model).
#
# </details>

# %% [markdown]
# **Pregunta:** ¿Notaste alguna diferencia en el número de falsos positivos o falsos negativos que produjo el modelo?

# %% [markdown]
# Escribe tu respuesta aquí. Haz doble clic (o presiona Enter) para editar.

# %% [markdown]
# **Pregunta:** ¿Qué crees que se podría hacer para mejorar el rendimiento del modelo?

# %% [markdown]
# Escribe tu respuesta aquí. Haz doble clic (o presiona Enter) para editar.

# %% [markdown]
# ## Consideraciones
#
# **¿Cuáles son algunas conclusiones clave que aprendiste de este laboratorio?**
#
# [Escribe tu respuesta aquí. Haz doble clic (o presiona Enter) para editar.]
#
# **¿Qué hallazgos compartirías con otros?**
#
# [Escribe tu respuesta aquí. Haz doble clic (o presiona Enter) para editar.]
#
# **¿Qué recomendarías a las partes interesadas?**
#
# [Escribe tu respuesta aquí. Haz doble clic (o presiona Enter) para editar.]

# %% [markdown]
# **¡Felicidades!** Has completado este laboratorio. Sin embargo, es posible que no notes una marca de verificación verde junto a este elemento en la plataforma de Coursera. Por favor, continúa con tu progreso independientemente de la marca de verificación. Solo haz clic en el icono de "guardar" en la parte superior de este cuaderno para asegurarte de que tu trabajo ha sido registrado.
